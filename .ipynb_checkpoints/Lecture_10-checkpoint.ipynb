# %% [markdown]
# # Multi-Layer Perceptron with MNIST handwritten digits classification

# %% [markdown]
# 아래의 코드에서 주석 처리 되어 있는 부분을 채워 넣으시면 됩니다.

# %% [markdown]
# ## 1. Module Import

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
from torchvision import datasets
import torchvision.transforms as transforms
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8324/2622835663.py in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 import torch
#       5 from torchvision import datasets
#       6 import torchvision.transforms as transforms
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# ## 2. 딥러닝 모델을 설계할 때 활용하는 장비 확인

# %%
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print('Using PyTorch version:', torch.__version__, ' Device:', device)
# Out:
# Using PyTorch version: 1.10.0  Device: cpu

# %% [markdown]
# ## 3. MNIST 데이터 다운로드 (Train data와 Test data 분리하기)

# %%
BATCH_SIZE = 32

train_data = datasets.MNIST('./data', train=True, download=True, transform=transforms.ToTensor())
test_data = # 여기에 코드를 채워 넣으세요

train_loader = torch.utils.data.DataLoader(dataset=train_data, batch_size=BATCH_SIZE, shuffle=False)
test_loader = # 여기에 코드를 채워 넣으세요

# %% [markdown]
# ## 4. 첫번째 batch 데이터의 크기와 타입을 확인하기

# %%
for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break

# %% [markdown]
# ## 5. 첫번째 batch 데이터를 시각화하여 확인하기

# %%
pltsize=1
plt.figure(figsize=(10*pltsize, pltsize))

for i in range(10):
    plt.subplot(1,10,i+1)
    plt.axis('off')
    # 아래와 같이 보이도록 수정하세요
    plt.title('Class: '+str(y_train[i].item()))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Gradient Descent 문제
# 주어진 함수 f를 최소로 만드는 x 값을 pytorch 라이브러리를 이용하여 찾으세요.

# %%
def f(x):
    x = np.array(x)
    return x[0]**2+x[1]**2

# %% [markdown]
# 위 함수는 벡터를 입력으로 받습니다.

# %%
x = torch.tensor([10,20], dtype=torch.float, requires_grad = True)

# %% [markdown]
# 초기값은 아래와 같이 설정합니다.

# %% [markdown]
# loss 값은 함수 f 에 위 초기값 x 을 입력한 값입니다. 우리는 이 loss 값을 최소로 만드는 x 값을 찾는 것이 목표입니다.

# %%
loss = f(x)
print(loss)

# %%
# loss 값을 미분합니다.

# %% [markdown]
# x 에 대하여 loss 값을 미분한 값을 구합니다. 즉 $\nabla_x f$ 값을 구합니다.

# %%
# 미분한 값을 구합니다.

# %% [markdown]
# 1.학습 속도 (learning rate)를 정합니다.
#
# 2.그 후 반복적으로 x 값을 변경합니다.
#
# 3.변경된 x를 다시 함수 f에 넣고 실제로 x값이 변경함에 따라 함수 f가 줄어드는 것을 확인합니다.

# %%
learning_rate = 0.1
for i in range(20):
    
    loss = # 함수 f 에 새로운 x 값을 입력합니다. 
    # loss를 자동 미분합니다. 
    print(loss)

    with torch.no_grad():
        x = # 새로운 x 값을 gradient를 이용해 구합니다. 
        
    x.requires_grad = True
    print(x)

# %% [markdown]
#  x 이 수렴되는 예상값은 무엇입니까?
#  왜 그렇게 생각하나요?
#  아래 cell에서 함수 f를 Wireframe plots 으로 그려보시고 그림과 우리가 한 작업을 설명해보세요.

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# Grab some test data.
x = np.linspace(-1,1,100)
y = np.linspace(-1,1,100)

X,Y = np.meshgrid(x,y)

# Z 값을 결정하세요

# Plot a basic wireframe.
ax.# wireframe 으로 그림을 그리세요
plt.show()
